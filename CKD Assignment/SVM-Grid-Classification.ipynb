# %%
#importing the libtraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes',]]
dep= dataset["classification_yes"]

# %%
indep.shape
# Out:
# (399, 27)

# %%
dep
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 394     True
# 395     True
# 396     True
# 397     True
# 398    False
# Name: classification_yes, Length: 399, dtype: bool

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV
param_grid= {'kernel':['linear','rbf','poly'],'gamma':['auto','scale'], 'C':[10,100,1000,2000,3000]}
grid= GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')

#fitting the model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              scoring='f1_weighted', verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re= grid.cv_results_
#print(re)
grid_predictions= grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)

#print classification report
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)

# %%
print(cm)
print(clf_report)
# Out:
# [[51  0]
#  [ 0 82]]
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        51
#         True       1.00      1.00      1.00        82
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("the f1_macro value for the best parameter{}:".format(grid.best_params_),f1_macro)
# Out:
# the f1_macro value for the best parameter{'C': 10, 'gamma': 'auto', 'kernel': 'poly'}: 1.0

# %%
table= pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.007660      0.001427         0.008014        0.002411       10
# 1        0.010181      0.000299         0.007625        0.000756       10
# 2        0.017087      0.002069         0.007834        0.001307       10
# 3        0.007264      0.002127         0.007163        0.002426       10
# 4        0.006970      0.000435         0.005928        0.000424       10
# 5        0.012353      0.000795         0.007202        0.000687       10
# 6        0.006831      0.001078         0.006805        0.000690      100
# 7        0.006918      0.001653         0.007760        0.000848      100
# 8        0.015093      0.001357         0.008238        0.001481      100
# 9        0.007614      0.001046         0.008087        0.000912      100
# 10       0.009002      0.001476         0.008314        0.001441      100
# 11       0.015059      0.000748         0.008249        0.001139      100
# ...

# %%
# ============================================================
# PREDICT CKD FOR A NEW PATIENT
# ============================================================
patient_data = {
    'age'   : 48,
    'bp'    : 80,
    'al'    : 4,
    'su'    : 0,
    'bgr'   : 200,
    'bu'    : 100,
    'sc_val': 7.2,
    'sod'   : 130,
    'pot'   : 5.5,
    'hrmo'  : 8.5,
    'pcv'   : 28,
    'wc'    : 11000,
    'rc'    : 3.2,

    # 1 = Yes, 0 = No
    'sg_b'  : 0,   # Specific Gravity 1.010
    'sg_c'  : 1,   # Specific Gravity 1.015
    'sg_d'  : 0,   # Specific Gravity 1.020
    'sg_e'  : 0,   # Specific Gravity 1.025
    'rbc'   : 0,   # Red Blood Cells Normal
    'pc'    : 0,   # Pus Cells Normal
    'pcc'   : 1,   # Pus Cell Clumps Present
    'ba'    : 0,   # Bacteria Present
    'htn'   : 1,   # Hypertension
    'dm'    : 1,   # Diabetes
    'cad'   : 0,   # Coronary Artery Disease
    'appet' : 0,   # Good Appetite
    'pe'    : 1,   # Pedal Edema
    'ane'   : 1,   # Anemia
}

# %%
# Put all values into a dataframe
new_patient = pd.DataFrame([[
    patient_data['age'],
    patient_data['bp'],
    patient_data['al'],
    patient_data['su'],
    patient_data['bgr'],
    patient_data['bu'],
    patient_data['sc_val'],
    patient_data['sod'],
    patient_data['pot'],
    patient_data['hrmo'],
    patient_data['pcv'],
    patient_data['wc'],
    patient_data['rc'],
    patient_data['sg_b'],
    patient_data['sg_c'],
    patient_data['sg_d'],
    patient_data['sg_e'],
    patient_data['rbc'],
    patient_data['pc'],
    patient_data['pcc'],
    patient_data['ba'],
    patient_data['htn'],
    patient_data['dm'],
    patient_data['cad'],
    patient_data['appet'],
    patient_data['pe'],
    patient_data['ane'],
]], columns=indep.columns)

# %%
new_patient
# Out:
#    age  bp  al  su  bgr   bu   sc  sod  pot  hrmo  ...  rbc_normal  pc_normal  \
# 0   48  80   4   0  200  100  7.2  130  5.5   8.5  ...           0          0
#
#    pcc_present  ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  \
# 0            1           0        1       1        0          0       1
#
#    ane_yes
# 0        1
#
# [1 rows x 27 columns]

# %%
# Scale and predict
new_patient_scaled = sc.transform(new_patient)
result             = grid.predict(new_patient_scaled)
probability        = grid.predict_proba(new_patient_scaled)

# %%
# Show result
print("\n--- RESULT ---")
if result[0]:
    print("CKD DETECTED")
else:
    print("NO CKD DETECTED")

print(f"CKD Chance    : {probability[0][1]*100:.2f}%")
print(f"No CKD Chance : {probability[0][0]*100:.2f}%")
# Out:
# --- RESULT ---
# CKD DETECTED
# CKD Chance    : 100.00%
# No CKD Chance : 0.00%

# %%
#save model , file save as .sav
import pickle

# Save model
pickle.dump(grid, open("finalised_model_SVM.sav", 'wb'))

# Save scaler
pickle.dump(sc, open("scaler_SVM.sav", 'wb'))
